# %%
import pandas as pd

# %%
input_file = "delhi_airQuality_2015_daily.json"
df = pd.read_json(input_file)
df.columns = df.iloc[0]
df = df.reindex(df.index.drop(0))

# %%
input_file = "cpcb_dly_aq_delhi-2014.csv"
df = pd.read_csv(input_file)

# %%
df.head()
# Out:
#    Stn Code Sampling Date  State City/Town/Village/Area  \
# 0       531      01-01-14  Delhi                  Delhi
# 1       531      01-06-14  Delhi                  Delhi
# 2       531      01-09-14  Delhi                  Delhi
# 3       531      15-01-14  Delhi                  Delhi
# 4       531      20-01-14  Delhi                  Delhi
#
#   Location of Monitoring Station                           Agency  \
# 0              Pritampura, Delhi  Central Pollution Control Board
# 1              Pritampura, Delhi  Central Pollution Control Board
# 2              Pritampura, Delhi  Central Pollution Control Board
# 3              Pritampura, Delhi  Central Pollution Control Board
# 4              Pritampura, Delhi  Central Pollution Control Board
#
#                      Type of Location  SO2  NO2  RSPM/PM10  PM 2.5
# 0  Residential, Rural and other Areas    4   40      154.0     NaN
# 1  Residential, Rural and other Areas    4   41      232.0     NaN
# ...

# %%
df['Date'] = pd.to_datetime(df['Sampling Date'])
df.drop(['Sampling Date'], axis = 1)
# Out:
#      Stn Code  State City/Town/Village/Area  \
# 0         531  Delhi                  Delhi
# 1         531  Delhi                  Delhi
# 2         531  Delhi                  Delhi
# 3         531  Delhi                  Delhi
# 4         531  Delhi                  Delhi
# 5         531  Delhi                  Delhi
# 6         531  Delhi                  Delhi
# 7         531  Delhi                  Delhi
# 8         531  Delhi                  Delhi
# 9         531  Delhi                  Delhi
# 10        531  Delhi                  Delhi
# 11        531  Delhi                  Delhi
# 12        531  Delhi                  Delhi
# 13        531  Delhi                  Delhi
# 14        531  Delhi                  Delhi
# 15        531  Delhi                  Delhi
# 16        531  Delhi                  Delhi
# 17        531  Delhi                  Delhi
# 18        531  Delhi                  Delhi
# 19        531  Delhi                  Delhi
# ...

# %%
df.to_csv('test_2014.csv')
